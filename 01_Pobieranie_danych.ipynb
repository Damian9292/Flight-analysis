# %% [markdown]
#  # Opis notatnika
#
#  Ten notatnik inicjuje naszą pracę nad warsztatem końcowym. Naszym zadaniem tutaj jest pobranie udostępnionych nam danych do obszaru roboczego, które w następnym kroku wgramy na naszą bazę danych. Ich obróbka oraz analiza zostanie przeprowadzona w specjalnie do tego celu przygotowanych kolejnych notatnikach.
#
#  Na potrzeby tego warsztatu został stworzony dedykowany serwis API, który dostępny jest pod adresem: https://api-datalab.coderslab.com/api/v2. Dodatkowo udostępniona została dokumentacja, z którą można zapoznać się tutaj: [klik](https://api-datalab.coderslab.com/v2/docs/).
#
#  > Dokumentacja jest czysto techniczna i ma na celu prezentację dostępnych endpointów wraz ze zwracanym typem. W celu przetestowania należy kliknąć przysisk `Authorize`, podać token (dostępny poniżej), a następnie `Try it out!` oraz uzupełnić wymagane pola (parametry requesta).
#
#  Zgodnie z dokumentacją stwierdzamy, że udostępnione zostały nam 4 endpointy:
#  - `airport` - dane o lotnisku,
#  - `weather` - informacje o zarejestrowaniej pogodzie na lotnisku danego dnia,
#  - `aircraft` - dane o samolotach
#  - `flights` - dane o wylotach z danego lotniska per dzień.
#
#  Wszystkie te źródła musimy pobrać, aby być w stanie wykonać całość warsztatu. W celu pobrania informacji, gdzie wymagany jest paramatr `airportId`, posłużymy się listą z pliku `airports.csv`.
#
#  Przy wykonywaniu tego zadania możesz posłużyć się tym tokenem: `iKRsQ8vdqgT903o2vH1rsejOeQ0F7YC9TvutH6Wk`.
#
#  ### Uwagi
#  - Ze względów ćwiczeniowych, konstrukcja poszczególnych endpointów jest różna – w trakcie pracy dokładnie przyjrzyj się, w jaki sposób należy wykonać zapytanie, aby otrzymać odpowiedź.
#  - Pamiętaj o dodaniu `sleep` pomiędzy poszczególnymi wywołaniami endpoint.
#  - Limit wywołań API to 1000/min, zadbaj o nieprzekroczenie tego limitu – w przeciwnym wypadku będzie zwracany błąd 429.

# %% [markdown]
#  # Konfiguracja notatnika

# %% [markdown]
#  Tutaj zaimportuj wymagane biblioteki

# %%
import json
import pandas as pd
import requests
from time import sleep
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
#  Tutaj zdefiniuj paramatry połączenia do API

# %%
API_KEY = "iKRsQ8vdqgT903o2vH1rsejOeQ0F7YC9TvutH6Wk"
API_URL = "https://api-datalab.coderslab.com/api/v2"

AUTH = {'authorization': API_KEY}

SLEEP = 60/950  # czas pomiędzy kolejnymi żądaniami w sekundach

# %% [markdown]
#  Tutaj wczytaj plik `airports.csv` i dostosuj do dalszych kroków w celu pobierania z kolejnych endpointów. Lista lotnisk jest dostępna w kolumnie `origin_airport_id`.

# %%
file_path = "C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/airports.csv"  #ścieżka do pliku
df = pd.read_csv(file_path)
df.head(5)
# Out:
#    origin_airport_id
# 0              10874
# 1              11233
# 2              13360
# 3              15008
# 4              11638

# %% [markdown]
#  # Pobieranie `Airport`
#  Zapoznaj się z dokumentacją endpointu `airport`, a następnie pobierz dane dot. poszczególnych lotnisk. Wyniki tego kroku zapisz do ramki `airport_df`, a następnie zapisz do pliku `csv`.
#
#  ### Wskazówki
#  - Nie wszystkie lotniska dostępne w pliku `airports.csv`, są dostępne w endpoint. Zadbaj o odpowiednie obsłużenie takiej sytuacji,
#  - Do skonwertowania wyników przydatna może okazać się metoda `Pandas` - [from_records](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.from_records.html),
#  - Artykuł LMS: `Python - analiza danych > Dzień 4 - API > Uwierzytelnianie`
#  - Artykuł LMS: `Python - analiza danych > Przygotowanie do zjazdu 2`

# %% [markdown]
#  Tutaj pobierz dane z endpoint'u `airport`

# %%
# Zamień DataFrame na listę
lista = df.values.tolist()

# Rozpakowanie do listy jednowymiarowej
flat_list = [item for sublist in lista for item in sublist]
  
# Pusta lista na dane o lotniskach
airport_data = []

# Pobieranie danych dla każdego identyfikatora
for airport_id in flat_list:
    url = f"{API_URL}/airport/{airport_id}"
    response = requests.get(url, headers={'authorization': API_KEY})
    if response.status_code == 200:
        airport_data.append(response.json())
    else:
        print(f"Błąd pobierania danych dla lotniska o ID {airport_id}")

# Tworzenie ramki danych z wyników
airport_df = pd.DataFrame.from_records(airport_data)
# Out:
# Błąd pobierania danych dla lotniska o ID 10874
# Błąd pobierania danych dla lotniska o ID 11233
# Błąd pobierania danych dla lotniska o ID 13360
# Błąd pobierania danych dla lotniska o ID 15008
# Błąd pobierania danych dla lotniska o ID 14150
# Błąd pobierania danych dla lotniska o ID 15323
# Błąd pobierania danych dla lotniska o ID 14814
# Błąd pobierania danych dla lotniska o ID 12007
# Błąd pobierania danych dla lotniska o ID 11337
# Błąd pobierania danych dla lotniska o ID 15070
# Błąd pobierania danych dla lotniska o ID 12280
# Błąd pobierania danych dla lotniska o ID 11641
# Błąd pobierania danych dla lotniska o ID 13832
# Błąd pobierania danych dla lotniska o ID 10268
# Błąd pobierania danych dla lotniska o ID 15041
# Błąd pobierania danych dla lotniska o ID 12119
# Błąd pobierania danych dla lotniska o ID 11537
# Błąd pobierania danych dla lotniska o ID 11092
# Błąd pobierania danych dla lotniska o ID 10581
# Błąd pobierania danych dla lotniska o ID 13829
# Błąd pobierania danych dla lotniska o ID 15389
# Błąd pobierania danych dla lotniska o ID 12389
# Błąd pobierania danych dla lotniska o ID 11648
# Błąd pobierania danych dla lotniska o ID 15023
# Błąd pobierania danych dla lotniska o ID 11982
# Błąd pobierania danych dla lotniska o ID 10967
# Błąd pobierania danych dla lotniska o ID 11525
# Błąd pobierania danych dla lotniska o ID 14259
# Błąd pobierania danych dla lotniska o ID 11637
# Błąd pobierania danych dla lotniska o ID 10466
# Błąd pobierania danych dla lotniska o ID 10208
# Błąd pobierania danych dla lotniska o ID 15841
# Błąd pobierania danych dla lotniska o ID 12898
# Błąd pobierania danych dla lotniska o ID 13241
# Błąd pobierania danych dla lotniska o ID 13367
# Błąd pobierania danych dla lotniska o ID 11481
# Błąd pobierania danych dla lotniska o ID 14108
# Błąd pobierania danych dla lotniska o ID 13873
# Błąd pobierania danych dla lotniska o ID 10157
# Błąd pobierania danych dla lotniska o ID 10245
# Błąd pobierania danych dla lotniska o ID 11146
# Błąd pobierania danych dla lotniska o ID 13277
# Błąd pobierania danych dla lotniska o ID 11109
# Błąd pobierania danych dla lotniska o ID 13459
# Błąd pobierania danych dla lotniska o ID 11775
# Błąd pobierania danych dla lotniska o ID 16218
# Błąd pobierania danych dla lotniska o ID 14698
# Błąd pobierania danych dla lotniska o ID 14252
# Błąd pobierania danych dla lotniska o ID 13256
# Błąd pobierania danych dla lotniska o ID 13139
# Błąd pobierania danych dla lotniska o ID 12250
# Błąd pobierania danych dla lotniska o ID 11468
# Błąd pobierania danych dla lotniska o ID 14952
# Błąd pobierania danych dla lotniska o ID 12402
# Błąd pobierania danych dla lotniska o ID 14574
# Błąd pobierania danych dla lotniska o ID 11977
# Błąd pobierania danych dla lotniska o ID 11867
# Błąd pobierania danych dla lotniska o ID 11203
# Błąd pobierania danych dla lotniska o ID 10747
# Błąd pobierania danych dla lotniska o ID 14905
# Błąd pobierania danych dla lotniska o ID 12012
# Błąd pobierania danych dla lotniska o ID 14783
# Błąd pobierania danych dla lotniska o ID 10431
# Błąd pobierania danych dla lotniska o ID 10434
# Błąd pobierania danych dla lotniska o ID 16869
# Błąd pobierania danych dla lotniska o ID 10408
# Błąd pobierania danych dla lotniska o ID 11624
# Błąd pobierania danych dla lotniska o ID 13541
# Błąd pobierania danych dla lotniska o ID 13422
# Błąd pobierania danych dla lotniska o ID 14689
# Błąd pobierania danych dla lotniska o ID 12391
# Błąd pobierania danych dla lotniska o ID 10868
# Błąd pobierania danych dla lotniska o ID 14711
# Błąd pobierania danych dla lotniska o ID 11067
# Błąd pobierania danych dla lotniska o ID 10562
# Błąd pobierania danych dla lotniska o ID 11695
# Błąd pobierania danych dla lotniska o ID 14109
# Błąd pobierania danych dla lotniska o ID 13970
# Błąd pobierania danych dla lotniska o ID 11076
# Błąd pobierania danych dla lotniska o ID 14092
# Błąd pobierania danych dla lotniska o ID 11122
# Błąd pobierania danych dla lotniska o ID 11288
# Błąd pobierania danych dla lotniska o ID 11308
# Błąd pobierania danych dla lotniska o ID 10754
# Błąd pobierania danych dla lotniska o ID 12884
# Błąd pobierania danych dla lotniska o ID 14588
# Błąd pobierania danych dla lotniska o ID 12915
# Błąd pobierania danych dla lotniska o ID 11603
# Błąd pobierania danych dla lotniska o ID 14457
# Błąd pobierania danych dla lotniska o ID 12206
# Błąd pobierania danych dla lotniska o ID 11252
# Błąd pobierania danych dla lotniska o ID 11905
# Błąd pobierania danych dla lotniska o ID 14120
# Błąd pobierania danych dla lotniska o ID 11980
# Błąd pobierania danych dla lotniska o ID 14025
# Błąd pobierania danych dla lotniska o ID 11150
# Błąd pobierania danych dla lotniska o ID 14709
# Błąd pobierania danych dla lotniska o ID 15897
# Błąd pobierania danych dla lotniska o ID 14006
# Błąd pobierania danych dla lotniska o ID 12902
# Błąd pobierania danych dla lotniska o ID 13061
# Błąd pobierania danych dla lotniska o ID 12016
# Błąd pobierania danych dla lotniska o ID 14794
# Błąd pobierania danych dla lotniska o ID 11921
# Błąd pobierania danych dla lotniska o ID 10731
# Błąd pobierania danych dla lotniska o ID 14828
# Błąd pobierania danych dla lotniska o ID 12441
# Błąd pobierania danych dla lotniska o ID 14802
# Błąd pobierania danych dla lotniska o ID 13230
# Błąd pobierania danych dla lotniska o ID 10631
# Błąd pobierania danych dla lotniska o ID 10141
# Błąd pobierania danych dla lotniska o ID 13184
# Błąd pobierania danych dla lotniska o ID 10643
# Błąd pobierania danych dla lotniska o ID 10333
# Błąd pobierania danych dla lotniska o ID 12255
# Błąd pobierania danych dla lotniska o ID 14487
# Błąd pobierania danych dla lotniska o ID 12129
# Błąd pobierania danych dla lotniska o ID 10551
# Błąd pobierania danych dla lotniska o ID 14256
# Błąd pobierania danych dla lotniska o ID 13377
# Błąd pobierania danych dla lotniska o ID 10627
# Błąd pobierania danych dla lotniska o ID 12335
# Błąd pobierania danych dla lotniska o ID 14633
# Błąd pobierania danych dla lotniska o ID 11274
# Błąd pobierania danych dla lotniska o ID 14543
# Błąd pobierania danych dla lotniska o ID 10158
# Błąd pobierania danych dla lotniska o ID 12951
# Błąd pobierania danych dla lotniska o ID 14004
# Błąd pobierania danych dla lotniska o ID 12544
# Błąd pobierania danych dla lotniska o ID 10739
# Błąd pobierania danych dla lotniska o ID 10165
# Błąd pobierania danych dla lotniska o ID 13964
# Błąd pobierania danych dla lotniska o ID 14314
# Błąd pobierania danych dla lotniska o ID 10990
# Błąd pobierania danych dla lotniska o ID 14812
# Błąd pobierania danych dla lotniska o ID 10561
# Błąd pobierania danych dla lotniska o ID 10146
# Błąd pobierania danych dla lotniska o ID 15991
# Błąd pobierania danych dla lotniska o ID 15401
# Błąd pobierania danych dla lotniska o ID 11587
# Błąd pobierania danych dla lotniska o ID 14520
# Błąd pobierania danych dla lotniska o ID 10185
# Błąd pobierania danych dla lotniska o ID 14534
# Błąd pobierania danych dla lotniska o ID 11111
# Błąd pobierania danych dla lotniska o ID 15024
# Błąd pobierania danych dla lotniska o ID 12917
# Błąd pobierania danych dla lotniska o ID 12124
# Błąd pobierania danych dla lotniska o ID 12523
# Błąd pobierania danych dla lotniska o ID 11630
# Błąd pobierania danych dla lotniska o ID 10170
# Błąd pobierania danych dla lotniska o ID 12448
# Błąd pobierania danych dla lotniska o ID 10918
# Błąd pobierania danych dla lotniska o ID 15356
# Błąd pobierania danych dla lotniska o ID 13344
# Błąd pobierania danych dla lotniska o ID 10676
# Błąd pobierania danych dla lotniska o ID 10926
# Błąd pobierania danych dla lotniska o ID 12156
# Błąd pobierania danych dla lotniska o ID 12244
# Błąd pobierania danych dla lotniska o ID 10666
# Błąd pobierania danych dla lotniska o ID 11612
# Błąd pobierania danych dla lotniska o ID 13476
# Błąd pobierania danych dla lotniska o ID 13029
# Błąd pobierania danych dla lotniska o ID 15411
# Błąd pobierania danych dla lotniska o ID 14986
# Błąd pobierania danych dla lotniska o ID 11471
# Błąd pobierania danych dla lotniska o ID 10155
# Błąd pobierania danych dla lotniska o ID 13486
# Błąd pobierania danych dla lotniska o ID 14716
# Błąd pobierania danych dla lotniska o ID 13296
# Błąd pobierania danych dla lotniska o ID 11283
# Błąd pobierania danych dla lotniska o ID 10732
# Błąd pobierania danych dla lotniska o ID 11003
# Błąd pobierania danych dla lotniska o ID 12094
# Błąd pobierania danych dla lotniska o ID 13158
# Błąd pobierania danych dla lotniska o ID 13121
# Błąd pobierania danych dla lotniska o ID 14877
# Błąd pobierania danych dla lotniska o ID 12217
# Błąd pobierania danych dla lotniska o ID 10372
# Błąd pobierania danych dla lotniska o ID 13264
# Błąd pobierania danych dla lotniska o ID 10469
# Błąd pobierania danych dla lotniska o ID 11336
# Błąd pobierania danych dla lotniska o ID 14112
# Błąd pobierania danych dla lotniska o ID 13502
# Błąd pobierania danych dla lotniska o ID 15027
# Błąd pobierania danych dla lotniska o ID 11973
# Błąd pobierania danych dla lotniska o ID 10361
# Błąd pobierania danych dla lotniska o ID 13388
# Błąd pobierania danych dla lotniska o ID 10577
# Błąd pobierania danych dla lotniska o ID 13290
# Błąd pobierania danych dla lotniska o ID 11577
# Błąd pobierania danych dla lotniska o ID 11140
# Błąd pobierania danych dla lotniska o ID 15048
# Błąd pobierania danych dla lotniska o ID 14960
# Błąd pobierania danych dla lotniska o ID 15295
# Błąd pobierania danych dla lotniska o ID 11865
# Błąd pobierania danych dla lotniska o ID 11049
# Błąd pobierania danych dla lotniska o ID 11953
# Błąd pobierania danych dla lotniska o ID 12223
# Błąd pobierania danych dla lotniska o ID 14254
# Błąd pobierania danych dla lotniska o ID 11823
# Błąd pobierania danych dla lotniska o ID 15380
# Błąd pobierania danych dla lotniska o ID 11447
# Błąd pobierania danych dla lotniska o ID 12003
# Błąd pobierania danych dla lotniska o ID 14489
# Błąd pobierania danych dla lotniska o ID 14082
# Błąd pobierania danych dla lotniska o ID 14113
# Błąd pobierania danych dla lotniska o ID 12891
# Błąd pobierania danych dla lotniska o ID 15249
# Błąd pobierania danych dla lotniska o ID 12819
# Błąd pobierania danych dla lotniska o ID 12323
# Błąd pobierania danych dla lotniska o ID 12343
# Błąd pobierania danych dla lotniska o ID 13076
# Błąd pobierania danych dla lotniska o ID 11503
# Błąd pobierania danych dla lotniska o ID 11617
# Błąd pobierania danych dla lotniska o ID 10728
# Błąd pobierania danych dla lotniska o ID 10785
# Błąd pobierania danych dla lotniska o ID 14674
# Błąd pobierania danych dla lotniska o ID 12197
# Błąd pobierania danych dla lotniska o ID 14696
# Błąd pobierania danych dla lotniska o ID 10781
# Błąd pobierania danych dla lotniska o ID 10849
# Błąd pobierania danych dla lotniska o ID 14955
# Błąd pobierania danych dla lotniska o ID 13433
# Błąd pobierania danych dla lotniska o ID 15074
# Błąd pobierania danych dla lotniska o ID 13127
# Błąd pobierania danych dla lotniska o ID 11013
# Błąd pobierania danych dla lotniska o ID 10154
# Błąd pobierania danych dla lotniska o ID 10980
# Błąd pobierania danych dla lotniska o ID 14098
# Błąd pobierania danych dla lotniska o ID 14512
# Błąd pobierania danych dla lotniska o ID 12278
# Błąd pobierania danych dla lotniska o ID 13933
# Błąd pobierania danych dla lotniska o ID 11997
# Błąd pobierania danych dla lotniska o ID 11027
# Błąd pobierania danych dla lotniska o ID 15582
# Błąd pobierania danych dla lotniska o ID 11721
# Błąd pobierania danych dla lotniska o ID 12896
# Błąd pobierania danych dla lotniska o ID 10279
# Błąd pobierania danych dla lotniska o ID 11778
# Błąd pobierania danych dla lotniska o ID 12888
# Błąd pobierania danych dla lotniska o ID 11415
# Błąd pobierania danych dla lotniska o ID 10685
# Błąd pobierania danych dla lotniska o ID 14842
# Błąd pobierania danych dla lotniska o ID 12265
# Błąd pobierania danych dla lotniska o ID 14288
# Błąd pobierania danych dla lotniska o ID 12397
# Błąd pobierania danych dla lotniska o ID 15624
# Błąd pobierania danych dla lotniska o ID 10409
# Błąd pobierania danych dla lotniska o ID 12519
# Błąd pobierania danych dla lotniska o ID 10136
# Błąd pobierania danych dla lotniska o ID 15607
# Błąd pobierania danych dla lotniska o ID 14237
# Błąd pobierania danych dla lotniska o ID 10779
# Błąd pobierania danych dla lotniska o ID 11898
# Błąd pobierania danych dla lotniska o ID 11413
# Błąd pobierania danych dla lotniska o ID 13983
# Błąd pobierania danych dla lotniska o ID 10558
# Błąd pobierania danych dla lotniska o ID 10620
# Błąd pobierania danych dla lotniska o ID 14222
# Błąd pobierania danych dla lotniska o ID 11097
# Błąd pobierania danych dla lotniska o ID 15454
# Błąd pobierania danych dla lotniska o ID 12899
# Błąd pobierania danych dla lotniska o ID 10135
# Błąd pobierania danych dla lotniska o ID 12177
# Błąd pobierania danych dla lotniska o ID 13795
# Błąd pobierania danych dla lotniska o ID 12945
# Błąd pobierania danych dla lotniska o ID 12511

# %%
airport_df
# Out:
#     ORIGIN_AIRPORT_ID              DISPLAY_AIRPORT_NAME  ORIGIN_CITY_NAME  \
# 0               11638               Fresno Air Terminal        Fresno, CA
# 1               13342            General Mitchell Field     Milwaukee, WI
# 2               13244             Memphis International       Memphis, TN
# 3               15096    Syracuse Hancock International      Syracuse, NY
# 4               10397                 Atlanta Municipal       Atlanta, GA
# ..                ...                               ...               ...
# 92              13198         Kansas City International   Kansas City, MO
# 93              10423  Austin - Bergstrom International        Austin, TX
# 94              15370               Tulsa International         Tulsa, OK
# 95              13303               Miami International         Miami, FL
# 96              10693        Myrtle Beach International  Myrtle Beach, SC
#
#                                                  NAME
# 0                FRESNO YOSEMITE INTERNATIONAL, CA US
# 1                   MILWAUKEE MITCHELL AIRPORT, WI US
# 2                MEMPHIS INTERNATIONAL AIRPORT, TN US
# 3       SYRACUSE HANCOCK INTERNATIONAL AIRPORT, NY US
# 4   ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ..                                                ...
# 92           KANSAS CITY INTERNATIONAL AIRPORT, MO US
# 93      AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 94     OKLAHOMA CITY WILL ROGERS WORLD AIRPORT, OK US
# 95                 MIAMI INTERNATIONAL AIRPORT, FL US
# 96                          NORTH MYRTLE BEACH, SC US
#
# [97 rows x 4 columns]

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić czy ta część została poprawnie wykonana

# %%
airport_df_expected_shape = (97, 4)
assert airport_df_expected_shape == airport_df.shape

# %% [markdown]
#  Tutaj zapisz ramkę `airport_df` do pliku `airport_list.csv`

# %%
# Zapisz ramkę danych do pliku CSV
airport_df.to_csv('C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/raw/airport_list.csv', index=False)

# %% [markdown]
#  # Pobieranie `Weather`
#  Zapoznaj się z dokumentacją endpotu `Weather`, następnie pobierz dane dotyczące zarejestrowanej pogody na poszczególnych lotniskach. Wyniki zapisz do ramki `weather_df`, a później do pliku `airport_weather.csv`.
#
#  Wskazówki:
#  - Ze względu na wolumen danych, które tutaj się pobiorą, odradzamy zapisywanie danych bezpośrednio do ramki. Rekomendujemy podejście podobne do tego z warsztatu na kursie `Python - analiza danych` - `Dzień 10 - Warsztat > Warsztat > Scrapowanie danych`, czyli stworzenie listy, a następnie przekonwertowanie jej w postać ramki.
#  - Data początkowa danych to `2019-01-01`, zaś data końcowa to `2020-03-31`, czyli 15 miesięcy,
#  - Ze względu na czas, jaki ten krok będzie się wykonywał, warto dodać w pętli instrukcję (lub kilka) `print`, aby monitorować przebieg wykonywania tego kroku.
#  - Przy dodawaniu miesięcy do daty może przydać się metoda [relativedelta](https://www.geeksforgeeks.org/python-get-month-from-year-and-weekday/).

# %%
endpoint = "/airportWeather"
# Ustawienie dat początkowej i końcowej
start_date = datetime(2019, 1, 1)
end_date = datetime(2020, 3, 31)
# Lista, która będzie przechowywać dane
weather_data = []
current_date = start_date
# Pętla przez okres czasu
while current_date <= end_date:
    # Formatowanie daty
    formatted_date = current_date.strftime("%Y-%m-%d")
    # Tworzenie URL-a z odpowiednią datą
    url = f"{API_URL}{endpoint}?date={formatted_date}"
    # Wykonanie zapytania HTTP
    response = requests.get(url, headers={'authorization': API_KEY})
    # Sprawdzenie poprawności odpowiedzi
    if response.status_code == 200:
        data = response.json()
        weather_data.extend(data)
        print(f"Pobrano dane dla {formatted_date}")
    else:
        print(f"Błąd pobierania danych dla {formatted_date}")
    # Przejście do kolejnego miesiąca
    current_date += relativedelta(months=1)
    sleep(0.5)

# Przekształcenie słownika w ramkę danych
weather_df = pd.DataFrame.from_records(weather_data)

# Wyświetlenie ramki danych
weather_df
# Out:
# Pobrano dane dla 2019-01-01
# Pobrano dane dla 2019-02-01
# Pobrano dane dla 2019-03-01
# Pobrano dane dla 2019-04-01
# Pobrano dane dla 2019-05-01
# Pobrano dane dla 2019-06-01
# Pobrano dane dla 2019-07-01
# Pobrano dane dla 2019-08-01
# Pobrano dane dla 2019-09-01
# Pobrano dane dla 2019-10-01
# Pobrano dane dla 2019-11-01
# Pobrano dane dla 2019-12-01
# Pobrano dane dla 2020-01-01
# Pobrano dane dla 2020-02-01
# Pobrano dane dla 2020-03-01
#        WT18      STATION                                               NAME  \
# 0      None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 1      None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 2      None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 3      None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# 4      None  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
# ...     ...          ...                                                ...
# 46221  None  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46222  None  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46223  None  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46224  None  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
# 46225  None  USW00014762             PITTSBURGH ALLEGHENY CO AIRPORT, PA US
#
#              DATE   AWND  PRCP  SNOW  SNWD  TAVG  TMAX  ...    PGTM  WT10  \
# 0      2019-01-01   4.70  0.14   0.0   0.0  64.0  66.0  ...     NaN   NaN
# 1      2019-01-02   4.92  0.57   0.0   0.0  56.0  59.0  ...     NaN   NaN
# 2      2019-01-03   5.37  0.15   0.0   0.0  52.0  55.0  ...     NaN   NaN
# 3      2019-01-04  12.08  1.44   0.0   0.0  56.0  66.0  ...     NaN   NaN
# 4      2019-01-05  13.42  0.00   0.0   0.0  49.0  59.0  ...     NaN   NaN
# ...           ...    ...   ...   ...   ...   ...   ...  ...     ...   ...
# 46221  2020-03-27   3.58  0.21   NaN   NaN   NaN  59.0  ...   146.0   NaN
# 46222  2020-03-28   6.93  1.29   NaN   NaN   NaN  77.0  ...  1535.0   NaN
# 46223  2020-03-29  16.55  0.02   NaN   NaN   NaN  78.0  ...  1408.0   NaN
# 46224  2020-03-30  13.42  0.00   NaN   NaN   NaN  57.0  ...   817.0   NaN
# 46225  2020-03-31   3.80  0.06   NaN   NaN   NaN  47.0  ...   110.0   NaN
#
#        WESD  SN32  SX32  PSUN  TSUN  TOBS  WT07  WT11
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...
# 46221   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46222   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46223   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46224   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 46225   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [46226 rows x 33 columns]

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
airport_weather_df_expected_shape = (46226, 33)
assert airport_weather_df_expected_shape == weather_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `weather_df` do pliku `airport_weather.csv` w katalogu `data/raw`

# %%
weather_df.to_csv('C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/raw/airport_weather.csv', index=False)

# %% [markdown]
#  # Pobranie `Aircraft`
#  Zapoznaj się z dokumentacją endpointu `aircraft`, a następnie pobierz dane produkcyjne samolotów. Wyniki zapisz do ramki `aircraft_df`, a następnie zapisz do pliku `aircraft.csv`.

# %%
# Endpoint
endpoint = "/aircraft"

# Lista, która będzie przechowywać dane
aircraft_data = []

# Tworzenie URL-a
url = f"{API_URL}{endpoint}"

# Wykonanie zapytania HTTP
response = requests.get(url, headers={'authorization': API_KEY})

# Sprawdzenie poprawności odpowiedzi
if response.status_code == 200:
    data = response.json()
    # Zachowanie danych w liście
    aircraft_data.extend(data)
    print("Dane zostały pobrane i zapisane w liście.")
else:
    print("Błąd podczas pobierania danych")
sleep(0.01)

# Przekształcenie listy w ramkę danych
aircraft_df = pd.DataFrame.from_dict(aircraft_data)

# Wyświetlenie ramki danych
aircraft_df
# Out:
# Dane zostały pobrane i zapisane w liście.
#       MANUFACTURE_YEAR TAIL_NUM  NUMBER_OF_SEATS
# 0                 1944   N54514              0.0
# 1                 1945   N1651M              0.0
# 2                 1953   N100CE              0.0
# 3                 1953   N141FL              0.0
# 4                 1953   N151FL              0.0
# ...                ...      ...              ...
# 7378              2019   N14011            337.0
# 7379              2019   N16008            337.0
# 7380              2019   N16009            337.0
# 7381              2019   N2250U            276.0
# 7382              2019   N2749U            276.0
#
# [7383 rows x 3 columns]

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
aircraft_df_expected_shape = (7383, 3)
assert aircraft_df_expected_shape == aircraft_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `aircraft_df` do pliku `aircraft.csv` w katalogu `data/raw`

# %%
aircraft_df.to_csv('C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/raw/aircraft.csv', index=False)

# %% [markdown]
#  # Pobranie `Flight`
#  Zapoznaj się z dokumentacją endpointu `flights`, następnie pobierz dane dotyczące ruchu lotniczego. Wyniki zapisz do ramki `flight_df`, a później do pliku `flight.csv`.
#
#  Wskazówki:
#  - Zwróć szczególną uwagę na konstrukcję endpointa,
#  - Ze względu na wolumen danych, które tutaj się pobiorą, odradzamy zapisywanie danych bezpośrednio do ramki. Rekomendujemy podejście podobne do tego, z warsztatu na kursie `Python - analiza danych` - `Dzień 10 - Warsztat > Warsztat > Scrapowanie danych`,
#  - Data początkowa danych to `2019-01-01`, zaś końcowa to `2020-03-31`, czyli 456 dni,
#  - Ze względu na czas, jaki ten krok będzie się wykonywał, warto dodać w pętli instrukcję (lub kilka) `print`, aby monitorować przebieg wykonywania tego kroku,
#  - W przypadku, gdy nie ma dostępnych danych dla danego lotniska, API zwraca kod [204](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/204), w ten sposób możesz pominąć lotniska, dla których dane nie są dostępne,
#  - Pobranie całości danych zajmuje dłuższą chwilę, zanim włączysz pętle dla wszystkich danych, sprawdź pobieranie danych dla jednego, dwóch lotnisk aby uniknąć frustracji.

# %%
# Otwarcie pliku csv z apirpots_id
file_folder= "C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/airports.csv"  #ścieżka do pliku
df_airports_id = pd.read_csv(file_folder)

# Zamień DataFrame na listę
origin_airport_ids = df_airports_id['origin_airport_id'].tolist()

endpoint_ft = '/flight'

# Lista do przechowywania danych o pogodzie na lotniskach
flight_data_list = []

# Data początkowa i końcowa
start_date = datetime(2019, 1, 1)

current_date = start_date
# Pobranie danych dla każdego lotniska
for airport_id in origin_airport_ids:
    # Pętla przez okres czasu
    current_date = start_date
    for i in range(15):
        # Formatowanie daty
        formatted_date = current_date.strftime("%Y-%m")
        # Tworzenie URL-a
        url = f"{API_URL}{endpoint_ft}?date={formatted_date}&airportId={airport_id}"
        # Wykonanie zapytania HTTP
        response = requests.get(url, headers={'authorization': API_KEY})
        # Sprawdzenie poprawności odpowiedzi
        if response.status_code == 200:
            data = response.json()
            if data:  # Sprawdzenie, czy dane istnieją
                flight_data_list.extend(data)
                print(f"Data downloaded for airport {airport_id} on {formatted_date}")
            else:
                print(f"No data available for the airport {airport_id} on {formatted_date}")
        elif response.status_code == 204:
            print(f"No data available for the airport {airport_id} on {formatted_date}")
            break
    # Przejście do kolejnej daty
        current_date += relativedelta(months=1)

# Przekształcenie słownika w ramkę danych
flight_df = pd.DataFrame.from_records(flight_data_list)

# Wyświetlenie ramki danych
flight_df

# %%
flight_df
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM  \
# 0            1            20            7                WN   N204WN
# 1            1            20            7                WN   N8682B
# 2            1            20            7                WN   N717SA
# 3            1            20            7                WN   N709SW
# 4            1            20            7                WN   N7864B
# ...        ...           ...          ...               ...      ...
# 1386115      3            26            4                DL   N350DN
# 1386116      3            26            4                DL   N908DE
# 1386117      3            26            4                DL      NaN
# 1386118      3            26            4                DL   N352NW
# 1386119      3            26            4                DL   N352DN
#
#          OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  CRS_DEP_TIME  \
# 0                      682              10397            11292           605
# 1                     2622              10397            11292          2120
# 2                     2939              10397            11292          1800
# 3                     3848              10397            11292          1355
# 4                     1352              10397            11697          1125
# ...                    ...                ...              ...           ...
# 1386115               1982              13303            12953          1956
# 1386116               1987              13303            10397          1120
# 1386117               1998              13303            10397          1817
# 1386118               2025              13303            10397          1937
# 1386119               2151              13303            12953           700
#
#          DEP_TIME  ...  CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME  DISTANCE  \
# 0           602.0  ...               205               204.0      1199
# 1          2114.0  ...               210               205.0      1199
# 2          1807.0  ...               210               220.0      1199
# 3          1354.0  ...               205               204.0      1199
# 4          1125.0  ...               120               124.0       581
# ...           ...  ...               ...                 ...       ...
# 1386115    1944.0  ...               183               169.0      1096
# 1386116    1117.0  ...               121               109.0       594
# 1386117       NaN  ...               125                 NaN       594
# 1386118    1928.0  ...               123               107.0       594
# 1386119       NaN  ...               183                 NaN      1096
#
#          DISTANCE_GROUP  YEAR CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0                     5  2019           NaN            NaN        NaN
# 1                     5  2019           NaN            NaN        NaN
# 2                     5  2019           4.0            0.0       10.0
# 3                     5  2019           NaN            NaN        NaN
# 4                     3  2019           NaN            NaN        NaN
# ...                 ...   ...           ...            ...        ...
# 1386115               5  2020           NaN            NaN        NaN
# 1386116               3  2020           NaN            NaN        NaN
# 1386117               3  2020           NaN            NaN        NaN
# 1386118               3  2020           NaN            NaN        NaN
# 1386119               5  2020           NaN            NaN        NaN
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   0.0                  3.0
# 3                   NaN                  NaN
# 4                   NaN                  NaN
# ...                 ...                  ...
# 1386115             NaN                  NaN
# 1386116             NaN                  NaN
# 1386117             NaN                  NaN
# 1386118             NaN                  NaN
# 1386119             NaN                  NaN
#
# [1386120 rows x 27 columns]

# %% [markdown]
#  ## Sprawdzenie
#  Uruchom kod poniżej, aby sprawdzić, czy ta część została poprawnie wykonana

# %%
flight_df_expected_shape = (1386120, 27)
assert flight_df_expected_shape == flight_df.shape

# %% [markdown]
#  ## Zapis do pliku
#  Tutaj zapisz ramkę `flight_df` do pliku `flight.csv` w katalogu `data/raw`

# %%
flight_df.to_csv('C:/Users/User/OneDrive - AEI/Pulpit/Pliki_do_Portfolio_Lab/data/raw/flight.csv', index=False)

# %% [markdown]
#  # Podsumowanie
#  W tym notatniku wykonaliśmy podstawowy krok w analizie danych - pozyskaliśmy je. Są gotowe do dalszej pracy, czyli możemy załadować je na bazę danych, a następnie zapoznać się z tym, jakie informacje ze sobą niosą. Kolejne notatniki będą służyły właśnie tym celom.

# %%
msg = "Wszystko wygląda OK :) Możesz przejść do kolejnego kroku."
print(msg)
# Out:
# Wszystko wygląda OK :) Możesz przejść do kolejnego kroku.
